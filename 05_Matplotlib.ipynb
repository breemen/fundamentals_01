# %% [markdown]
# <div align="center">
# <a href="https://vbti.nl"><img src="./images/vbti_logo.png" width="400"></a>
# </div>
#
# # Matplotlib
#
# There are many packages to visualize data in Python. One of the most used package is [Matplotlib](https://matplotlib.org/). This package can be used to visualize data from Python, Numpy, and Pandas easily.

# %%
# import numpy, pandas en matplotlib
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
mpl.__version__
# Out:
# '3.2.2'

# %%
# basic plot
x = np.linspace(-1, 1, 10)
y = x**2
plt.plot(x, y);

# %%
# Matplotlib provides different plotting styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# classical style
with plt.style.context(('classic')):
    plt.plot(x, y);

# %%
# modern style
with plt.style.context(('seaborn-whitegrid')):
    plt.plot(x, y);

# %%
# plot examples in all available styles
for i in range(len(plt.style.available)):
    plt.figure(figsize=(4, 3))
    with plt.style.context((plt.style.available[i])):
        plt.plot(x, y)
        plt.title(plt.style.available[i])
        plt.xlabel('x')
        plt.ylabel('y')
        plt.show()

# %% [markdown]
# ## Saving a figure
#
# Any plot can be saved to a file with the `savefig()` method.

# %%
x = np.linspace(0, 10, 25)
fig = plt.figure(figsize=(6,4))
plt.plot(x, np.sin(2 * np.pi * x / 10), '-');
plt.plot(x, np.cos(2 * np.pi * x / 10), '--');
plt.savefig('example01.png')

# %%
# the following image formats are supported
fig.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# ## Matlab interface vs. object-oriented interface
#
# Matplotlib provides two interfaces to create graphs.
# The first method is based on the 'stateful' plot functionality of Matlab. Below you see an example. In this case you use a global figure.

# %%
plt.figure(figsize=(8,6))
plt.subplot(2,1,1)
plt.plot(x, np.sin(x))
plt.subplot(2,1,2)
plt.plot(x, np.cos(x));

# %% [markdown]
# The second method is object-oriented, as illustrated below. Here you plot on a specific you have created.

# %%
fig, ax = plt.subplots(2, figsize=(8,6))
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %% [markdown]
# Here, the axis `ax` object is used to plot. In the 'stateful Matlab' interface, the state is remembered internally by the matplotlib package.

# %% [markdown]
# ## Graph design
#
# Matplotlib provides many options to plot line graphs.

# %%
fig, ax = plt.subplots(3, figsize=(8,8))
# line color: 'blue', '0.6' (grayscale), '(0.2, 0.4, 0.5)' (rgb). '#AA02FF' Hex code RRGGBB
ax[0].plot(x, np.sin(x), color='blue')
# line style: '-', '--', '-.', ':'
ax[1].plot(x, np.cos(x), linestyle=':')
# marker style: 'o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd'
ax[2].plot(x, np.cos(x), marker='x');

# %%
# Labels and limits
fig, ax = plt.subplots(2, figsize=(8,6))
ax[0].plot(x, np.sin(x), color='blue')
ax[0].set_xlim(-2, 12)
ax[0].set_ylim(-1.2, 1.2)
ax[0].set_title("sin")
ax[0].set_xlabel("x")
ax[0].set_ylabel("y")
ax[1].plot(x, np.cos(x), linestyle=':')
ax[1].set_xlim(-2, 12)
ax[1].set_ylim(-1.2, 1.2)
ax[1].set_title("cos")
ax[1].set_xlabel("x")
ax[1].set_ylabel("y")
# voorkom overlap van labels met tight_layout()
plt.tight_layout()

# %%
# Complete graph example
fig, ax = plt.figure(figsize=(8,4)), plt.axes()
ax.plot(x, np.sin(x), color='blue', label="sin(x)")
ax.plot(x, np.cos(x), linestyle=':', label="cos(x)")
ax.set(xlim=(-2, 12), ylim=(-1.2, 1.2), title="Example line graph", xlabel="x", ylabel="y")
plt.legend();

# %% [markdown]
# The grid of a plot can be turned off or customized using `plt.grid()`.

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,6))

ax[0].plot(x, np.sin(x), color='blue')
ax[0].grid(False)
ax[0].set(xlim=(-2, 12), ylim=(-1.2, 1.2), title="No grid", xlabel="x", ylabel="y")
ax[1].plot(x, np.sin(x), color='blue')
ax[1].grid(True, linewidth=3, color='r', linestyle='-.')
ax[1].set(xlim=(-2, 12), ylim=(-1.2, 1.2), title="Custom grid style", xlabel="x", ylabel="y")

# adjust layout to avoid overlap
plt.tight_layout();

# %% [markdown]
# ## Scatter plot

# %%
x = np.random.normal(0, 2, size=100)
y = np.random.normal(0, 1, size=100)
fig, ax = plt.figure(figsize=(5, 5)), plt.axes()
ax.scatter(x, y)
ax.set(xlim=(-6,6), ylim=(-6,6), xlabel="x", ylabel="y", title="scatter plot");

# %% [markdown]
# The marker type of a scatter plot can be adjusted. For a complete overview see https://matplotlib.org/api/markers_api.html.

# %%
from matplotlib.markers import MarkerStyle
MarkerStyle.markers
fig, ax = plt.subplots(figsize=(12, 12))
ncols = 6
for i, m in enumerate(MarkerStyle.markers.keys()):
    ax.scatter(i%ncols, -int(i/ncols), marker=m, s=100)
    ax.text(i%ncols, -int(i/ncols)-0.4, '{} : {}'.format(m,MarkerStyle.markers[m]), ha="center")
ax.set(xlim=(-0.15, ncols + 0.15), ylim=(-int(len(MarkerStyle.markers)/ncols)-0.15, 0.15), title="type markers")
plt.axis('off');

# %%
# create an array with a color for every data point
colors = 1 - (np.abs(x) / np.max(np.abs(x)))

# create an array with a marker size for every data point
sizes  = 500 * (np.abs(y) / np.max(np.abs(y)))

# create figure
fig, ax = plt.figure(figsize=(5, 5)), plt.axes()

# create plot
# select colormap (cmap), see https://matplotlib.org/gallery/color/colormap_reference.html
# or https://matplotlib.org/examples/color/colormaps_reference.html
im = ax.scatter(x, y, c=colors, s=sizes, alpha=0.7, cmap='inferno')
ax.set(xlim=(-6,6), ylim=(-6,6), xlabel="x", ylabel="y", title="scatter plot")

# add colorbar
fig.colorbar(im, ax=ax, orientation='horizontal');

# %% [markdown]
# ## Subplots with different sizes
#
# To plot multiple figures with the same size, use `plt.subplots()`. To plot graphs with different sizes, use the [GridSpec](https://matplotlib.org/api/_as_gen/matplotlib.gridspec.GridSpec.html#matplotlib.gridspec.GridSpec) object.

# %%
import matplotlib.gridspec as gridspec

fig = plt.figure(figsize=(8, 6))
gs = gridspec.GridSpec(2, 2, height_ratios=[2, 1])
ax1 = plt.subplot(gs[0, :])
ax2 = plt.subplot(gs[1, 0])
ax3 = plt.subplot(gs[1, 1])

x = np.linspace(0, 10, 25)
ax1.plot(x, np.sin(2 * np.pi * x / 5), '.');
ax2.plot(x, np.sin(2 * np.pi * x / 10), '-');
ax3.plot(x, np.cos(2 * np.pi * x / 10), '--');

# %% [markdown]
# ## Plot images and matrices
#
# Matplotlib can plot images using the `plt.imshow()` method.

# %%
img = plt.imread('./images/big.jpg')
img.shape
# Out:
# (1280, 960, 3)

# %%
# plot image
plt.imshow(img);

# %%
# plot an array
A = np.random.normal(0, 1, (200, 20))
plt.imshow(A);

# %%
# plot an array with adjusted aspect ratio 
# aspect: 'auto', 'equal', scalar
# interpolation: 'none', 'nearest', 'bilinear', 'bicubic', 'gaussian'
plt.imshow(A, aspect='auto', interpolation='none');

# %%
# add a colorbar
plt.imshow(A, aspect='auto', interpolation='none');
plt.colorbar(orientation='horizontal', shrink=0.8, fraction=0.1);

# %% [markdown]
# # 3D plots
#
# Matplotlib also supports plotting 3D data.
#
# ## Plot surface

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
x, y = np.meshgrid(x, y)
z = x**2 + y**2 - 0.5*x*y

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, rstride=2, cstride=2, cmap='viridis', linewidth=0)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

# define elevation (z) en azimuth (x,y) of Axes object
ax.view_init(40, 60)

# %% [markdown]
# ## Plot 3d line

# %%
z = np.linspace(0, 10, 100)
x = 10 * np.sin(z)
y = 10 * np.cos(z)

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')
p = ax.plot(x, y, z, c='r', lw=2)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

# define elevation (z) en azimuth (x,y) of Axes object
ax.view_init(40, 60)

# %% [markdown]
# ## Plot contour plot

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
x, y = np.meshgrid(x, y)
z = x**2 + y**2 - 0.5*x*y

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)

ax.contour(x, y, z, 15, linewidths = 0.5, colors = 'k')
p = ax.pcolormesh(x, y, z, cmap = plt.get_cmap('viridis'))
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.colorbar(p, ax=ax);
